# %%
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\ongha\OneDrive\Documents\GitHub\SiGeSn_Atomic_Descriptors\MEAs_SISSO

# %%
# Replace 'your_file.csv' with the path to your CSV file
X = pd.read_csv('test_features_purelocalcomp.csv')

# Display the first 5 rows of the DataFrame
print(df.head())
# Out:
#    rho_diff  %Si       %Ge       %Sn
# 0 -0.002004    0  0.500000  0.500000
# 1 -0.001932    0  0.428571  0.571429
# 2 -0.001981    0  0.428571  0.571429
# 3 -0.001947    0  0.428571  0.571429
# 4 -0.000723    0  0.428571  0.571429

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)  # You can reduce to fewer components if desired
principal_components = pca.fit_transform(X_scaled)

# %%
plt.scatter(principal_components[:, 0], principal_components[:, 1])
